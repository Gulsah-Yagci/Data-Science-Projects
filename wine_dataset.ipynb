# %% [markdown]
# # Wine Review

# %% [markdown]
# <img src='head_wine.jpg' style="height: 400px; width: 500px"></img>

# %% [markdown]
# ## Content
#
# 1. [Business Understanding](1)
# 2. [Importing Libraries](1)
# 3. [Load Dataset](2)
# 4. [Exploratory Data Analysis](3)

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# Explore wine dataset

# %% [markdown]
# <a id='1'></a>
# ## Importing Libraries

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# general
import pandas as pd
import numpy as np

# for visualization
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# statistics
import scipy as sp

# %% [markdown]
# ## Load Dataset

# %%
wine = pd.read_csv('wine_dataset.csv')
df = wine.copy()
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# 'Unnamed: 0' is a id series. We don't need this.

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Information about Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 12.9+ MB

# %% [markdown]
# ### Features Description
#
# * unnamed 0: Ids of rows
#
# * country: The country that the wine is from
#
# * description: Reviews of tasters
#
# * designation: The vineyard within the winery where the grapes that made the wine are from
#
# * points: The number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post reviews for
#
# * price: The cost for a bottle of the wine
#
# * province: The province or state that the wine is from
#
# * region_1: The wine growing area in a province or state (ie Napa)
#
# * region_2: Sometimes there are more specific regions specified within a wine growing area (ie Rutherford inside the Napa Valley), but this
#
# * taster_name: tasters' names
#
# * taster_twitter_handle: Tasters' twitter account names
#
# * title: wine name
#
# * variety:
#
# * winery:

# %%
# dataset's columns
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 13

# %%
# dataset's shape
df.shape
# Out:
# (129971, 13)

# %%
df.size
# Out:
# 1689623

# %%
df.ndim
# Out:
# 2

# %%
# is there any null values?
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
msno.matrix(df.sample(129971))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df.sample(129971))
# Out:
# <AxesSubplot:>

# %%
 msno.dendrogram(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Statistics

# %%
df.describe().T
# Out:
#            count       mean        std   min   25%   50%   75%     max
# points  129971.0  88.447138   3.039730  80.0  86.0  88.0  91.0   100.0
# price   120975.0  35.363389  41.022218   4.0  17.0  25.0  42.0  3300.0

# %%
df.corr()
# Out:
#           points     price
# points  1.000000  0.416167
# price   0.416167  1.000000

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.heatmap(df.corr(),annot=True,cmap= 'coolwarm');

# %% [markdown]
# ### Country

# %%
### How many countries are there?
print(df.country.unique())
print(len(df.country.unique()))
# Out:
# ['Italy' 'Portugal' 'US' 'Spain' 'France' 'Germany' 'Argentina' 'Chile'
#  'Australia' 'Austria' 'South Africa' 'New Zealand' 'Israel' 'Hungary'
#  'Greece' 'Romania' 'Mexico' 'Canada' nan 'Turkey' 'Czech Republic'
#  'Slovenia' 'Luxembourg' 'Croatia' 'Georgia' 'Uruguay' 'England' 'Lebanon'
#  'Serbia' 'Brazil' 'Moldova' 'Morocco' 'Peru' 'India' 'Bulgaria' 'Cyprus'
#  'Armenia' 'Switzerland' 'Bosnia and Herzegovina' 'Ukraine' 'Slovakia'
#  'Macedonia' 'China' 'Egypt']
# 44

# %%
country_nan = df.country.dropna()
print(country_nan.unique())
len(country_nan.unique())
# Out:
# ['Italy' 'Portugal' 'US' 'Spain' 'France' 'Germany' 'Argentina' 'Chile'
#  'Australia' 'Austria' 'South Africa' 'New Zealand' 'Israel' 'Hungary'
#  'Greece' 'Romania' 'Mexico' 'Canada' 'Turkey' 'Czech Republic' 'Slovenia'
#  'Luxembourg' 'Croatia' 'Georgia' 'Uruguay' 'England' 'Lebanon' 'Serbia'
#  'Brazil' 'Moldova' 'Morocco' 'Peru' 'India' 'Bulgaria' 'Cyprus' 'Armenia'
#  'Switzerland' 'Bosnia and Herzegovina' 'Ukraine' 'Slovakia' 'Macedonia'
#  'China' 'Egypt']
# 43

# %%
country_nan.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
sns.set(rc={'figure.figsize':(60,20)})
sns.barplot(x='country',y=df.country.index,data=df);
plt.title('Bar Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(60,20)})
sns.countplot(x="country", data=df)
plt.title('Count Plot')
plt.show()

# %%
pclass = pd.crosstab(index=df['country'],columns='frekans')
pclass.T
# Out:
# country  Argentina  Armenia  Australia  Austria  Bosnia and Herzegovina  \
# col_0
# frekans       3800        2       2329     3345                       2
#
# country  Brazil  Bulgaria  Canada  Chile  China  ...  Serbia  Slovakia  \
# col_0                                            ...
# frekans      52       141     257   4472      1  ...      12         1
#
# country  Slovenia  South Africa  Spain  Switzerland  Turkey     US  Ukraine  \
# col_0
# frekans        87          1401   6645            7      90  54504       14
#
# country  Uruguay
# col_0
# frekans      109
#
# [1 rows x 43 columns]

# %%
pclass/pclass.sum()
# Out:
# col_0                    frekans
# country
# Argentina               0.029251
# Armenia                 0.000015
# Australia               0.017928
# Austria                 0.025749
# Bosnia and Herzegovina  0.000015
# Brazil                  0.000400
# Bulgaria                0.001085
# Canada                  0.001978
# Chile                   0.034424
# China                   0.000008
# Croatia                 0.000562
# Cyprus                  0.000085
# Czech Republic          0.000092
# Egypt                   0.000008
# England                 0.000570
# France                  0.170067
# Georgia                 0.000662
# Germany                 0.016666
# Greece                  0.003587
# Hungary                 0.001124
# India                   0.000069
# Israel                  0.003887
# Italy                   0.150414
# Lebanon                 0.000269
# Luxembourg              0.000046
# Macedonia               0.000092
# Mexico                  0.000539
# ...

# %% [markdown]
# ### Description

# %%
#

# %% [markdown]
# ### Designation

# %%
### How many designations are there?
print(df.designation.unique())
print(len(df.designation.unique()))
# Out:
# ['Vulkà Bianco' 'Avidagos' nan ...
#  'Gimblett Gravels Merlot-Cabernet Sauvignon-Malbec' 'Irongate'
#  'Lieu-dit Harth Cuvée Caroline']
# 37980

# %%
designation_nan = df.designation.dropna()
print(designation_nan.unique())
len(designation_nan.unique())
# Out:
# ['Vulkà Bianco' 'Avidagos' 'Reserve Late Harvest' ...
#  'Gimblett Gravels Merlot-Cabernet Sauvignon-Malbec' 'Irongate'
#  'Lieu-dit Harth Cuvée Caroline']
# 37979

# %%
designation_nan.value_counts()
# Out:
# Reserve                                         2009
# Estate                                          1322
# Reserva                                         1259
# Riserva                                          698
# Estate Grown                                     621
#                                                 ...
# Zwischen den Seen Nr. 7 Trockenbeerenauslese       1
# Oppenheimer Sackträger Auslese                     1
# Cap Insula                                         1
# El Jabali Vineyard Brut Rosé                       1
# Grand'Arte Chardonnay                              1
# Name: designation, Length: 37979, dtype: int64

# %% [markdown]
# ### Points

# %%
len(df.points.unique())
# Out:
# 21

# %%
sns.set(rc={'figure.figsize':(60,10)})
sns.distplot(df['points'],kde=True)
plt.title('Points')
plt.show()

# %%
sns.set(rc={'figure.figsize':(40,20)})
sns.countplot(x="points", data=df)
plt.title('Count Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(30,10)})
sns.boxplot(x=df["points"])
plt.title('Box Plot')
plt.show()

# %% [markdown]
# ### Price

# %%
sns.set(rc={'figure.figsize':(60,10)})
sns.distplot(df['price'],kde=True)
plt.title('Wine Price')
plt.show()

# %%
sns.set(rc={'figure.figsize':(50,20)})
sns.countplot(x="price", data=df)
plt.title('Count Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(50,10)})
sns.boxplot(x=df["price"])
plt.title('Box Plot')
plt.show()

# %% [markdown]
# ### Province

# %%
province_nan = df.province.dropna()
print(province_nan.unique())
len(province_nan.unique())
# Out:
# ['Sicily & Sardinia' 'Douro' 'Oregon' 'Michigan' 'Northern Spain' 'Alsace'
#  'Rheinhessen' 'California' 'Mosel' 'Other' 'Mendoza Province' 'Virginia'
#  'Beaujolais' 'Colchagua Valley' 'Southern Italy' 'Maule Valley'
#  'Bordeaux' 'Maipo Valley' 'Washington' 'Central Italy' 'Champagne'
#  'Burgundy' 'South Australia' 'Tejo' 'Rapel Valley' 'Galicia'
#  'France Other' 'Tuscany' 'Burgenland' 'New York' 'Leyda Valley'
#  'Piedmont' 'Stellenbosch' 'Simonsberg-Stellenbosch' 'Walker Bay'
#  'Alentejano' 'Central Spain' 'Southwest France' 'Aconcagua Valley'
#  'Loncomilla Valley' 'Marlborough' 'Northeastern Italy'
#  'Casablanca Valley' 'Veneto' 'Western Cape' 'Judean Hills' 'Alentejo'
#  'Coastal Region' 'Rhône Valley' 'Galilee' 'Beira Atlantico' 'Tokaj'
#  'Leithaberg' 'Santorini' 'Kremstal' 'Catalonia' 'Recas' "Hawke's Bay"
#  'Curicó Valley' 'Limarí Valley' 'Colchagua Costa' 'Languedoc-Roussillon'
#  'Provence' 'Victoria' 'Rheingau' 'Tokaji' 'Naoussa' 'Valle de Guadalupe'
# ...

# %%
sns.set(rc={'figure.figsize':(50,20)})
sns.barplot(x='province',y=df.province.index,data=df);
plt.title('Bar Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(60,20)})
sns.countplot(x="province", data=df)
plt.title('Count Plot')
plt.show()

# %%
tab = pd.crosstab(index=df['province'],columns='frekans')
tab.T
# Out:
# province  Achaia  Aconcagua Costa  Aconcagua Valley  Aegean  Agioritikos  Ahr  \
# col_0
# frekans        5               27               116      22            3    9
#
# province  Alenquer  Alentejano  Alentejo  Alenteo  ...  Wellington  \
# col_0                                              ...
# frekans          7         937       182        1  ...          23
#
# province  Western Australia  Western Cape  Wiener Gemischter Satz  \
# col_0
# frekans                 286           281                      28
#
# province  Württemberg  Zenata  Österreichischer Perlwein  \
# col_0
# frekans            22      19                          4
#
# province  Österreichischer Sekt  Štajerska  Župa
# col_0
# frekans                      66         22     8
#
# [1 rows x 425 columns]

# %%
# %
tab_ = tab/tab.sum()
tab_.T
# Out:
# province    Achaia  Aconcagua Costa  Aconcagua Valley    Aegean  Agioritikos  \
# col_0
# frekans   0.000038         0.000208          0.000893  0.000169     0.000023
#
# province       Ahr  Alenquer  Alentejano  Alentejo   Alenteo  ...  Wellington  \
# col_0                                                         ...
# frekans   0.000069  0.000054    0.007213  0.001401  0.000008  ...    0.000177
#
# province  Western Australia  Western Cape  Wiener Gemischter Satz  \
# col_0
# frekans            0.002202      0.002163                0.000216
#
# province  Württemberg    Zenata  Österreichischer Perlwein  \
# col_0
# frekans      0.000169  0.000146                   0.000031
#
# province  Österreichischer Sekt  Štajerska      Župa
# col_0
# frekans                0.000508   0.000169  0.000062
#
# [1 rows x 425 columns]

# %% [markdown]
# ### Region_1 and Region_2

# %%
region_one_nan = df.region_1.dropna()
print(region_one_nan.unique())
len(region_one_nan.unique())
# Out:
# ['Etna' 'Willamette Valley' 'Lake Michigan Shore' ... 'Del Veneto'
#  'Bardolino Superiore' 'Paestum']
# 1229

# %%
sns.set(rc={'figure.figsize':(50,20)})
sns.barplot(x='region_1',y=df.region_1.index,data=df);
plt.title('Bar Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(60,20)})
sns.countplot(x="region_1", data=df)
plt.title('Count Plot')
plt.show()

# %%
tab = pd.crosstab(index=df['region_1'],columns='frekans')
tab.T
# Out:
# region_1  Abruzzo  Adelaida District  Adelaide  Adelaide Hills  \
# col_0
# frekans         6                110        16             107
#
# region_1  Adelaide Plains  Aglianico d'Irpinia  Aglianico del Beneventano  \
# col_0
# frekans                 4                    1                          2
#
# region_1  Aglianico del Taburno  Aglianico del Vulture  Agrelo  ...  \
# col_0                                                           ...
# frekans                      13                     90      50  ...
#
# region_1  Yadkin Valley  Yakima Valley  Yamhill County  Yarra Valley  Yecla  \
# col_0
# frekans               5            997               2           111     24
#
# region_1  Yolo County  York Mountain  Yorkville Highlands  Yountville  \
# col_0
# frekans            47              9                   79          92
#
# region_1  Zonda Valley
# col_0
# frekans              3
#
# [1 rows x 1229 columns]

# %%
# %
tab_ = tab/tab.sum()
tab_.T
# Out:
# region_1   Abruzzo  Adelaida District  Adelaide  Adelaide Hills  \
# col_0
# frekans   0.000055           0.001012  0.000147        0.000984
#
# region_1  Adelaide Plains  Aglianico d'Irpinia  Aglianico del Beneventano  \
# col_0
# frekans          0.000037             0.000009                   0.000018
#
# region_1  Aglianico del Taburno  Aglianico del Vulture   Agrelo  ...  \
# col_0                                                            ...
# frekans                 0.00012               0.000828  0.00046  ...
#
# region_1  Yadkin Valley  Yakima Valley  Yamhill County  Yarra Valley  \
# col_0
# frekans        0.000046        0.00917        0.000018      0.001021
#
# region_1     Yecla  Yolo County  York Mountain  Yorkville Highlands  \
# col_0
# frekans   0.000221     0.000432       0.000083             0.000727
#
# region_1  Yountville  Zonda Valley
# col_0
# frekans     0.000846      0.000028
#
# [1 rows x 1229 columns]

# %%
# region_2
region_two_nan = df.region_2.dropna()
print(region_two_nan.unique())
len(region_two_nan.unique())
# Out:
# ['Willamette Valley' 'Napa' 'Sonoma' 'Central Coast' 'Oregon Other'
#  'Central Valley' 'North Coast' 'Columbia Valley' 'California Other'
#  'Finger Lakes' 'Sierra Foothills' 'New York Other' 'Long Island'
#  'Napa-Sonoma' 'Southern Oregon' 'Washington Other' 'South Coast']
# 17

# %%
sns.set(rc={'figure.figsize':(50,20)})
sns.countplot(x="region_2", data=df)
plt.title('Count Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(50,20)})
sns.barplot(x='region_2',y=df.region_1.index,data=df);
plt.title('Bar Plot')
plt.show()

# %%
tab = pd.crosstab(index=df['region_2'],columns='frekans')
tab.T
# Out:
# region_2  California Other  Central Coast  Central Valley  Columbia Valley  \
# col_0
# frekans               2663          11065            1062             8103
#
# region_2  Finger Lakes  Long Island  Napa  Napa-Sonoma  New York Other  \
# col_0
# frekans           1777          680  6814         1169             231
#
# region_2  North Coast  Oregon Other  Sierra Foothills  Sonoma  South Coast  \
# col_0
# frekans           584           727              1462    9028          272
#
# region_2  Southern Oregon  Washington Other  Willamette Valley
# col_0
# frekans               917               534               3423

# %%
# %
tab_ = tab/tab.sum()
tab_.T
# Out:
# region_2  California Other  Central Coast  Central Valley  Columbia Valley  \
# col_0
# frekans           0.052721       0.219061        0.021025         0.160421
#
# region_2  Finger Lakes  Long Island      Napa  Napa-Sonoma  New York Other  \
# col_0
# frekans        0.03518     0.013462  0.134901     0.023143        0.004573
#
# region_2  North Coast  Oregon Other  Sierra Foothills    Sonoma  South Coast  \
# col_0
# frekans      0.011562      0.014393          0.028944  0.178733     0.005385
#
# region_2  Southern Oregon  Washington Other  Willamette Valley
# col_0
# frekans          0.018154          0.010572           0.067767

# %% [markdown]
# ### Taster name and Taster Twitter Handle

# %%
len(df.taster_name.unique())
# Out:
# 20

# %%
taster_name_nan = df.taster_name.dropna()
print(taster_name_nan.unique())
len(taster_name_nan.unique())
# Out:
# ['Kerin O’Keefe' 'Roger Voss' 'Paul Gregutt' 'Alexander Peartree'
#  'Michael Schachner' 'Anna Lee C. Iijima' 'Virginie Boone' 'Matt Kettmann'
#  'Sean P. Sullivan' 'Jim Gordon' 'Joe Czerwinski' 'Anne Krebiehl\xa0MW'
#  'Lauren Buzzeo' 'Mike DeSimone' 'Jeff Jenssen' 'Susan Kostrzewa'
#  'Carrie Dykes' 'Fiona Adams' 'Christina Pickard']
# 19

# %%
# the number of comments made by taster
df.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
# twitter account names of the tasters
df.groupby('taster_name')['taster_twitter_handle'].unique()
# Out:
# taster_name
# Alexander Peartree                 [nan]
# Anna Lee C. Iijima                 [nan]
# Anne Krebiehl MW           [@AnneInVino]
# Carrie Dykes                       [nan]
# Christina Pickard      [@winewchristina]
# Fiona Adams                   [@bkfiona]
# Jeff Jenssen            [@worldwineguys]
# Jim Gordon            [@gordone_cellars]
# Joe Czerwinski                  [@JoeCz]
# Kerin O’Keefe             [@kerinokeefe]
# Lauren Buzzeo                [@laurbuzz]
# Matt Kettmann            [@mattkettmann]
# Michael Schachner          [@wineschach]
# Mike DeSimone           [@worldwineguys]
# Paul Gregutt               [@paulgwine ]
# Roger Voss                  [@vossroger]
# Sean P. Sullivan         [@wawinereport]
# Susan Kostrzewa          [@suskostrzewa]
# Virginie Boone                 [@vboone]
# Name: taster_twitter_handle, dtype: object

# %%
sns.set(rc={'figure.figsize':(60,20)})
sns.countplot(x="taster_name", data=df)
plt.title('Count Plot')
plt.show()

# %%
tab = pd.crosstab(index=df['taster_name'],columns='frekans')
tab.T
# Out:
# taster_name  Alexander Peartree  Anna Lee C. Iijima  Anne Krebiehl MW  \
# col_0
# frekans                     415                4415              3685
#
# taster_name  Carrie Dykes  Christina Pickard  Fiona Adams  Jeff Jenssen  \
# col_0
# frekans               139                  6           27           491
#
# taster_name  Jim Gordon  Joe Czerwinski  Kerin O’Keefe  Lauren Buzzeo  \
# col_0
# frekans            4177            5147          10776           1835
#
# taster_name  Matt Kettmann  Michael Schachner  Mike DeSimone  Paul Gregutt  \
# col_0
# frekans               6332              15134            514          9532
#
# taster_name  Roger Voss  Sean P. Sullivan  Susan Kostrzewa  Virginie Boone
# col_0
# frekans           25514              4966             1085            9537

# %%
# %
tab_ = tab/tab.sum()
tab_.T
# Out:
# taster_name  Alexander Peartree  Anna Lee C. Iijima  Anne Krebiehl MW  \
# col_0
# frekans                0.004001            0.042564          0.035526
#
# taster_name  Carrie Dykes  Christina Pickard  Fiona Adams  Jeff Jenssen  \
# col_0
# frekans           0.00134           0.000058      0.00026      0.004734
#
# taster_name  Jim Gordon  Joe Czerwinski  Kerin O’Keefe  Lauren Buzzeo  \
# col_0
# frekans        0.040269        0.049621       0.103888       0.017691
#
# taster_name  Matt Kettmann  Michael Schachner  Mike DeSimone  Paul Gregutt  \
# col_0
# frekans           0.061045           0.145902       0.004955      0.091895
#
# taster_name  Roger Voss  Sean P. Sullivan  Susan Kostrzewa  Virginie Boone
# col_0
# frekans        0.245973          0.047876          0.01046        0.091943

# %% [markdown]
# ### Title

# %%
title_nan = df.title.dropna()
print(title_nan.unique())
len(title_nan.unique())
# Out:
# ['Nicosia 2013 Vulkà Bianco  (Etna)'
#  'Quinta dos Avidagos 2011 Avidagos Red (Douro)'
#  'Rainstorm 2013 Pinot Gris (Willamette Valley)' ...
#  'Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)'
#  'Domaine Marcel Deiss 2012 Pinot Gris (Alsace)'
#  'Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caroline Gewurztraminer (Alsace)']
# 118840

# %%
title_nan.value_counts()
# Out:
# Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma County)           11
# Korbel NV Brut Sparkling (California)                             9
# Segura Viudas NV Extra Dry Sparkling (Cava)                       8
# Gloria Ferrer NV Blanc de Noirs Sparkling (Carneros)              7
# Segura Viudas NV Aria Estate Extra Dry Sparkling (Cava)           7
#                                                                  ..
# Finca El Portillo 2008 Estate Bottled Chardonnay (Uco Valley)     1
# Umani Ronchi 2010 Montipagano  (Montepulciano d'Abruzzo)          1
# Rai 2013 Sauvignon Blanc (Central Valley)                         1
# Agustinos 2014 Reserva Malbec (Bío Bío Valley)                    1
# Adelsheim 2012 Pinot Gris (Willamette Valley)                     1
# Name: title, Length: 118840, dtype: int64

# %% [markdown]
# ### Variety

# %%
variety_nan = df.variety.dropna()
print(variety_nan.unique())
len(variety_nan.unique())
# Out:
# ['White Blend' 'Portuguese Red' 'Pinot Gris' 'Riesling' 'Pinot Noir'
#  'Tempranillo-Merlot' 'Frappato' 'Gewürztraminer' 'Cabernet Sauvignon'
#  'Nerello Mascalese' 'Chardonnay' 'Malbec' 'Tempranillo Blend' 'Meritage'
#  'Red Blend' 'Merlot' "Nero d'Avola" 'Chenin Blanc' 'Gamay'
#  'Sauvignon Blanc' 'Viognier-Chardonnay' 'Primitivo' 'Catarratto'
#  'Inzolia' 'Petit Verdot' 'Monica' 'Bordeaux-style White Blend' 'Grillo'
#  'Sangiovese' 'Cabernet Franc' 'Champagne Blend'
#  'Bordeaux-style Red Blend' 'Aglianico' 'Petite Sirah' 'Touriga Nacional'
#  'Carmenère' 'Albariño' 'Petit Manseng' 'Rosé' 'Zinfandel' 'Vernaccia'
#  'Rosato' 'Grüner Veltliner' 'Viognier' 'Vermentino' 'Grenache Blanc'
#  'Syrah' 'Nebbiolo' 'Shiraz-Cabernet Sauvignon' 'Pinot Blanc'
#  'Alsace white blend' 'Barbera' 'Rhône-style Red Blend' 'Portuguese White'
#  'Graciano' 'Tannat-Cabernet' 'Sauvignon' 'Sangiovese Grosso' 'Torrontés'
#  'Prugnolo Gentile' 'G-S-M' 'Verdejo' 'Fumé Blanc' 'Furmint'
# ...

# %%
variety_nan.value_counts()
# Out:
# Pinot Noir                  13272
# Chardonnay                  11753
# Cabernet Sauvignon           9472
# Red Blend                    8946
# Bordeaux-style Red Blend     6915
#                             ...
# Premsal                         1
# Mavrotragano                    1
# Petit Meslier                   1
# Schwartzriesling                1
# Parraleta                       1
# Name: variety, Length: 707, dtype: int64

# %% [markdown]
# ### Winery

# %%
winery_nan = df.winery.dropna()
print(winery_nan.unique())
len(winery_nan.unique())
# Out:
# ['Nicosia' 'Quinta dos Avidagos' 'Rainstorm' ... 'Mas de Pampelonne'
#  'Bodegas Eidosela' 'Penedo Borges']
# 16757

# %%
winery_nan.value_counts()
# Out:
# Wines & Winemakers    222
# Testarossa            218
# DFJ Vinhos            215
# Williams Selyem       211
# Louis Latour          199
#                      ...
# Winner's Tank           1
# Emery                   1
# Kuehn                   1
# Apogee                  1
# Terra de Falanis        1
# Name: winery, Length: 16757, dtype: int64

# %% [markdown]
# ## Bivarite Analysis
